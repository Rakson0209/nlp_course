# %% [markdown]
# ## From BNC to Ngram
#
# ### BNC Data:
# https://drive.google.com/file/d/1mKX1DLHDIqKph4e4k1MnYOV3iWtvT7-E/view?usp=sharing
#
# ### 1. Extract lines containing id, title, classcode, keywords, sentences from each BNC parts
#
# grep (global search regular RE)
# grep是很常見也很常用的命令，它的主要功能是進行字符串數據的比較，然後符合用戶需求的字符串打印出來，但是注意，grep在數據中查找一個字符串時，是以“整行”爲單位進行數據篩選的。
#
# egrep (extended RE)
#
# Reference
# https://www.twblogs.net/a/5d26d705bd9eee1e5c84509d

# %%
! time ! egrep -o -h \
'(<idno type="bnc">.*?</idno>|<title>.*?</title>|<classCode.*?</classCode>|<keywords>.*?</keywords>|<s n=".*?">|<w c5=".*?" hw=".*?" pos=".*?">.*?</w>|<c c5=".*?">.*?</c>|</s>|<p>|</p>)' \
BNC/Texts/*/*/G*.xml > BNC.G.txt

# %% [markdown]
# ####        Repeat Step 1 for all sections A, B, C, D, E, F, G, H, J, and K

# %% [markdown]
#  ### 2. Convert sentences to bigram (for all sections A to K, no I)
#  ### 2.1 Convert line to word tokens

# %%
import re
from pprint import pprint

def line_to_token(line):
    if line.startswith('<s'):
        return ('<s> ', '<s>', '<s>') 
    elif line.startswith('</s'):
        return ('</s>', '</s>', '</s>') 
    elif line.startswith('<w'):
        # <w c5="VVN" hw="discount" pos="VERB">discounted </w>
        match = re.findall('<w c5="(.*?)" hw="(.*?)" pos=".*?">(.*?)</w>', line)
        return (match[0][2].strip(), match[0][0].upper(), match[0][1]) # lemma, tag, word
    elif line.startswith('<c'):
        match = re.findall('<c c5="PUN">(.*?)</c>', line)
        if not match:
            return '??? line'
        return (match[0], match[0], match[0])

def tokens_to_bigram(tokens):
    result = []
    for i in range(len(tokens)-1):
        if i == 1:
            word2tag2lemma2 = [tokens[i][j].lower()+' '+tokens[i+1][j] for j in range(3)]
        else:
            word2tag2lemma2 = [tokens[i][j]+' '+tokens[i+1][j] for j in range(3)]
        if word2tag2lemma2[0][0].isalpha() or word2tag2lemma2[0][0] == '<': 
            result = result + [ '\t'.join(word2tag2lemma2) ]
    return result

# %% [markdown]
# ### 2.2 Convert token stream to bigram stream

# %%
def word_to_bigram(wordfile, bigramfile):
    
    def Batch_to_ngram(batch, fileout):        
        with open(wordfile.format(batch)) as filein:
            lines = filein.readlines()
            for i, line in enumerate(lines):
                if line.startswith('<s'):
                    sent_start = i
                elif line.startswith('</s'):
                    sentence = [line.strip() for line in lines[sent_start:i+1]]
                    tokens = [line_to_token(line) for line in sentence ]
                    #pprint (tokens)
                    bigram = tokens_to_bigram(tokens)
                    print('\n'.join(bigram), file=fileout)
    
    with open(bigramfile, 'w') as fileout:
        for batch in 'ABCDEFGHJK':
            Batch_to_ngram(batch, fileout)
                
word_to_bigram('BNC.{0}.txt', 'BNC.2w.txt')

# %% [markdown]
# ### 3 Sort and count bigram (word1 word2 \<tab\> count)

# %%
#1 BNC.2w.txt ==> BNC.2w.c.txt
! time sort BNC.2w.txt | uniq -c | \
awk '{ gsub(/^[ ]*/, ""); print }' | awk '{print substr($0, index($0, " ")+1) "\t" $1}' > BNC.2w.c.txt
# Out:
# sort BNC.2w.txt  354.56s user 890.55s system 69% cpu 29:40.28 total
# uniq -c  16.02s user 0.63s system 0% cpu 29:40.28 total
# awk '{ gsub(/^[ ]*/, ""); print }'  28.34s user 0.15s system 1% cpu 29:40.28 total
# awk '{print substr($0, index($0, " ")+1) "\t" $1}' > BNC.2w.c.txt  19.06s user 0.63s system 1% cpu 29:40.28 total

# %%
import os
import re
import string

# %%
def tokenize(text):
    """
    Input:
    "This is an example.'

    Sample output: 
    ['this', 'is', 'an', 'example', '.']
    """  
    #### [ TODO ] transform text to lower case
    text = text.lower()
    #### [ TODO ] seperate the words by white space
    tokens = text.translate(str.maketrans('','',string.punctuation)).split(' ')
    return tokens
    
from collections import Counter

def calculate_frequency(tokens):
    """
    Input:
    ['this', 'is', 'an', 'example', ...]

    Sample output: 
    {
        'the': 79809, 
        'project': 288,
        ...
    }
    """
    frequency = Counter(tokens)
    return frequency
    #### [ TODO ] 
   


def get_ngram(tokens, n=2):
    """
    Input:
    ['this', 'is', 'an', 'example', ...]

    Sample output: 
    ['this is', 'is an', 'an example', ...]
    """
    #### [TODO] 
    return [' '.join(tokens[i:i+n]) for i in range(len(tokens)-1)]

# %%
# Read lang-8 Data
file_path = os.path.join('data','clang8.txt')
lang_bigram = []
lang_accident_bigram = []

#### [ TODO ] generate lang8 unigrams and calculate document frequency of unigram in lang8
with open(file_path, 'r', encoding='UTF-8') as f:
    for line in f:
        tokens = tokenize(line)
        bigram = get_ngram(tokens)
        for word in bigram:
                if ' accident' in word:
                        lang_bigram.append(word)


lang_bigram_counter = calculate_frequency(lang_bigram)

# %%
lang_bigram_Rank = {}

#### [ TODO ] Rank unigrams for lang

sorted_lang_bigram = sorted(lang_bigram_counter.items(), key=lambda word: word[1],reverse=True)
j = 1
for i in sorted_lang_bigram:
    lang_bigram_Rank[i[0]] = j
    j = j+1

# %%
! egrep -o 'AJ0 NN.*accident[^AZaz].*' BNC.2w.c.txt > BNC.accident.txt

# %%
file_path = os.path.join('BNC.accident.txt')

BNC_bigram_counter = {}

with open(file_path, 'r', encoding='UTF-8') as f:
    for line in f:
        tokens =  line.split()
        if tokens[2] + ' ' + tokens[3] in BNC_bigram_counter.keys():
            BNC_bigram_counter[tokens[2] + ' ' + tokens[3]] = int(BNC_bigram_counter[tokens[2] + ' ' + tokens[3]])+ int(tokens[4])
        else:
            BNC_bigram_counter[tokens[2] + ' ' + tokens[3]] = int(tokens[4])

# %%
BNC_bigram_Rank = {}

#### [ TODO ] Rank unigrams for BNC

sorted_BNC_bigram = sorted(BNC_bigram_counter.items(), key=lambda word: word[1],reverse=True)
j = 1
for i in sorted_BNC_bigram:
    BNC_bigram_Rank[i[0]] = j
    j = j+1

# %%
BNC_bigram_Rank
# Out:
# {'fatal accident': 1,
#  'general accident': 2,
#  'serious accident': 3,
#  'personal accident': 4,
#  'nuclear accident': 5,
#  'major accident': 6,
#  'industrial accident': 7,
#  'tragic accident': 8,
#  'terrible accident': 9,
#  'nasty accident': 10,
#  'freak accident': 11,
#  'historical accident': 12,
#  'minor accident': 13,
#  'unfortunate accident': 14,
#  'bad accident': 15,
#  'similar accident': 16,
#  'horrific accident': 17,
#  'little accident': 18,
#  'recent accident': 19,
#  'actual accident': 20,
#  'happy accident': 21,
#  'pure accident': 22,
#  'medical accident': 23,
#  'mean accident': 24,
#  'hit-and-run accident': 25,
#  'particular accident': 26,
#  'possible accident': 27,
#  'appalling accident': 28,
#  'cerebrovascular accident': 29,
#  'high accident': 30,
#  'inevitable accident': 31,
#  'marine accident': 32,
#  'other accident': 33,
#  'reduce accident': 34,
#  'severe accident': 35,
#  'catastrophic accident': 36,
#  'complete accident': 37,
#  'domestic accident': 38,
#  'dreadful accident': 39,
#  'flying accident': 40,
#  'lucky accident': 41,
#  'mere accident': 42,
#  'strange accident': 43,
#  'avoidable accident': 44,
#  'big accident': 45,
#  'certain accident': 46,
#  'chemical accident': 47,
#  'climbing accident': 48,
#  'disabling accident': 49,
#  'drink-related accident': 50,
#  'horrible accident': 51,
#  'low accident': 52,
#  'non-fatal accident': 53,
#  'numerous accident': 54,
#  'occupational accident': 55,
#  'separate accident': 56,
#  'slight accident': 57,
#  'small accident': 58,
#  'spectacular accident': 59,
#  'total accident': 60,
#  'scottish accident': 61,
#  'awful accident': 62,
#  'common accident': 63,
#  'dangerous accident': 64,
#  'disastrous accident': 65,
#  'farming accident': 66,
#  'full accident': 67,
#  'genetic accident': 68,
#  'gory accident': 69,
#  'impending accident': 70,
#  'investigate accident': 71,
#  'just accident': 72,
#  'near accident': 73,
#  'official accident': 74,
#  'poor accident': 75,
#  'real accident': 76,
#  'related accident': 77,
#  'simple accident': 78,
#  'single accident': 79,
#  'social accident': 80,
#  'unnecessary accident': 81,
#  'early accident': 82,
#  'senior accident': 83,
#  'abseiling accident': 84,
#  'accident-free record': 85,
#  'bizarre accident': 86,
#  'cerebro-vascular accident': 87,
#  'combined accident': 88,
#  'drink-drive accident': 89,
#  'drink-driving accident': 90,
#  'drowning accident': 91,
#  'external accident': 92,
#  'fearful accident': 93,
#  'fortunate accident': 94,
#  'geographical accident': 95,
#  'good accident': 96,
#  'horrendous accident': 97,
#  'horrifying accident': 98,
#  'hypothetical accident': 99,
#  'improved accident': 100,
#  'inexplicable accident': 101,
#  'insignificant accident': 102,
#  'large accident': 103,
#  'loop accident': 104,
#  'lost-time accident': 105,
#  'military accident': 106,
#  'multi-vehicle accident': 107,
#  'national accident': 108,
#  'near-fatal accident': 109,
#  'negative accident': 110,
#  'new accident': 111,
#  'normal accident': 112,
#  'notorious accident': 113,
#  'onstage accident': 114,
#  'original accident': 115,
#  'parachuting accident': 116,
#  'peculiar accident': 117,
#  'permanent accident': 118,
#  'political accident': 119,
#  'potential accident': 120,
#  'predictable accident': 121,
#  'previous accident': 122,
#  'reportable accident': 123,
#  'sad accident': 124,
#  'scalding accident': 125,
#  'so-called accident': 126,
#  'specific accident': 127,
#  'sporting accident': 128,
#  'stupid accident': 129,
#  'sudden accident': 130,
#  'supposed accident': 131,
#  'unexplained accident': 132,
#  'unlucky accident': 133,
#  'various accident': 134,
#  'work-related accident': 135,
#  'boac accident': 136,
#  'british accident': 137,
#  'chernobyl-type accident': 138,
#  'palazzese accident': 139,
#  'soviet accident': 140,
#  'above accident': 141,
#  'abrupt accident': 142,
#  'accident-free flying': 143,
#  'accident-free period': 144,
#  'accident-free transport': 145,
#  'accident-free year': 146,
#  'accident-prone treasury': 147,
#  'accident-prone administration': 148,
#  'accident-prone challenger': 149,
#  'accident-prone filly': 150,
#  'accident-prone hero': 151,
#  'accident-prone politician': 152,
#  'accident-prone quality': 153,
#  'accident-prone reputation': 154,
#  'accident-prone routine': 155,
#  'accident-prone unit': 156,
#  'additional accident': 157,
#  'aerotow accident': 158,
#  'agricultural accident': 159,
#  'ballooning accident': 160,
#  'become accident': 161,
#  'best-known accident': 162,
#  'blameless accident': 163,
#  'blameworthy accident': 164,
#  'blame–free accident': 165,
#  'bleeding accident': 166,
#  'call accident': 167,
#  'cerebral accident': 168,
#  'claimable accident': 169,
#  'classified accident': 170,
#  'closed accident': 171,
#  'collusive accident': 172,
#  'completed accident': 173,
#  'conceivable accident': 174,
#  'considerable accident': 175,
#  'convenient accident': 176,
#  'cosmic accident': 177,
#  'cricketing accident': 178,
#  'crippling accident': 179,
#  'cruel accident': 180,
#  'curious accident': 181,
#  'devastating accident': 182,
#  'different accident': 183,
#  'dismal accident': 184,
#  'dive-bombing accident': 185,
#  'diving accident': 186,
#  'driving accident': 187,
#  'drive accident': 188,
#  'electrical accident': 189,
#  'empty accident': 190,
#  'entertaining accident': 191,
#  'environmental accident': 192,
#  'evolutionary accident': 193,
#  'exceptional accident': 194,
#  'expensive accident': 195,
#  'experienced accident': 196,
#  'famous accident': 197,
#  'fateful accident': 198,
#  'fictitious accident': 199,
#  'first-lap accident': 200,
#  'follow accident': 201,
#  'fortuitous accident': 202,
#  'free accident': 203,
#  'frequent accident': 204,
#  'fresh accident': 205,
#  'frightful accident': 206,
#  'future accident': 207,
#  'genealogical accident': 208,
#  'genuine accident': 209,
#  'gliding accident': 210,
#  'glide accident': 211,
#  'goddam accident': 212,
#  'heavy accident': 213,
#  'hefty accident': 214,
#  'heroic accident': 215,
#  'hideous accident': 216,
#  'huge accident': 217,
#  'hunting accident': 218,
#  'identifiable accident': 219,
#  'immediate accident': 220,
#  'incendiary accident': 221,
#  'increased accident': 222,
#  'injury-related accident': 223,
#  'innumerable accident': 224,
#  'interesting accident': 225,
#  'jack-knife accident': 226,
#  'key accident': 227,
#  'life-threatening accident': 228,
#  'likely accident': 229,
#  'local accident': 230,
#  'loss-of-coolant accident': 231,
#  'lowered accident': 232,
#  'ludicrous accident': 233,
#  'macabre accident': 234,
#  'major-accident ward': 235,
#  'measured accident': 236,
#  'miraculous accident': 237,
#  'mock accident': 238,
#  'move accident': 239,
#  'multiple accident': 240,
#  'mysterious accident': 241,
#  'naval accident': 242,
#  'night-time accident': 243,
#  'non-clustered accident': 244,
#  'notifiable accident': 245,
#  'nuclear accident.confusion': 246,
#  'obscure accident': 247,
#  'old accident': 248,
#  'one-off accident': 249,
#  'only accident': 250,
#  'onshore accident': 251,
#  'open accident': 252,
#  'operative accident': 253,
#  'ordinary accident': 254,
#  'over accident': 255,
#  'painful accident': 256,
#  'physiological accident': 257,
#  'plan accident': 258,
#  'playing accident': 259,
#  'pre-accident condition': 260,
#  'predicted accident': 261,
#  'preliminary accident': 262,
#  'quarrying accident': 263,
#  'quiet accident': 264,
#  'racing accident': 265,
#  'rare accident': 266,
#  'raw accident': 267,
#  'recommended accident': 268,
#  'recordable accident': 269,
#  'recreational accident': 270,
#  'reduced accident': 271,
#  'repeat accident': 272,
#  'reported accident': 273,
#  'resuscitated accident': 274,
#  'saved accident': 275,
#  'scattered accident': 276,
#  'seeming accident': 277,
#  'senseless accident': 278,
#  'shaming accident': 279,
#  'sheer accident': 280,
#  'shooting accident': 281,
#  'significant accident': 282,
#  'silly accident': 283,
#  'simulated accident': 284,
#  'skating accident': 285,
#  'skid accident': 286,
#  'sorry accident': 287,
#  'spin-related accident': 288,
#  'spin accident': 289,
#  'spontaneous accident': 290,
#  'sporadic accident': 291,
#  'sport accident': 292,
#  'structural accident': 293,
#  'subjective accident': 294,
#  'sublime accident': 295,
#  'subsequent accident': 296,
#  'substantial accident': 297,
#  'survivable accident': 298,
#  'tank-related accident': 299,
#  'taxying accident': 300,
#  'temporal accident': 301,
#  'theoretical accident': 302,
#  'third-party accident': 303,
#  'true accident': 304,
#  'two-car accident': 305,
#  'unavoidable accident': 306,
#  'uncharacteristic accident': 307,
#  'unconstrained accident': 308,
#  'underground accident': 309,
#  'undisclosed accident': 310,
#  'unforeseeable accident': 311,
#  'unknown accident': 312,
#  'unplanned accident': 313,
#  'unrecorded accident': 314,
#  'unspecified accident': 315,
#  'unsurvivable accident': 316,
#  'unthinkable accident': 317,
#  'urban accident': 318,
#  'wretched accident': 319}

# %%
import pandas as pd
df = pd.DataFrame(columns=['Phrases','Overuse rank/rank', 'BNC rank', 'Lang-8 rank'])
BNC_bigram_Rank_result = {}
lang_bigram_Rank_result= {}

### 找前30個 BNC 及 lang8 裡面都存在的adj. accident
j = 0
for bigram in BNC_bigram_Rank:
    if bigram in lang_bigram_Rank.keys():
        BNC_bigram_Rank_result[bigram] = j+1
        lang_bigram_Rank_result[bigram] = lang_bigram_Rank[bigram]
        j = j+1
        if j == 30:
            break
### 排序 lang8 前30個 adj. accident ranking
for i, element in enumerate(sorted(lang_bigram_Rank_result.items(), key=lambda word: word[1])):
    lang_bigram_Rank_result[element[0]] = i+1

for bigram in BNC_bigram_Rank_result:
    rank_ratio = BNC_bigram_Rank_result[bigram] / lang_bigram_Rank_result[bigram]
    df.loc[len(df)] = [bigram, round(rank_ratio, 2), BNC_bigram_Rank_result[bigram], lang_bigram_Rank_result[bigram]]

# %%
df
# Out:
#                      Phrases  Overuse rank/rank  BNC rank  Lang-8 rank
# 0             fatal accident               0.12         1            8
# 1           serious accident               0.40         2            5
# 2           nuclear accident               3.00         3            1
# 3             major accident               0.15         4           27
# 4        industrial accident               0.19         5           26
# 5            tragic accident               0.60         6           10
# 6          terrible accident               2.33         7            3
# 7        historical accident               0.32         8           25
# 8             minor accident               0.45         9           20
# 9       unfortunate accident               0.45        10           22
# 10              bad accident               2.75        11            4
# 11          similar accident               0.75        12           16
# 12           little accident               1.08        13           12
# 13           recent accident               0.78        14           18
# 14            happy accident               1.36        15           11
# 15             pure accident               1.23        16           13
# 16  cerebrovascular accident               0.89        17           19
# 17     catastrophic accident               0.64        18           28
# 18            lucky accident               1.36        19           14
# 19             mere accident               0.83        20           24
# 20              big accident              10.50        21            2
# 21         horrible accident               3.14        22            7
# 22            small accident               2.56        23            9
# 23            awful accident               1.60        24           15
# 24        dangerous accident               4.17        25            6
# 25             gory accident               0.87        26           30
# 26             just accident               0.93        27           29
# 27           simple accident               1.22        28           23
# 28           single accident               1.71        29           17
# 29              new accident               1.43        30           21

# %% [markdown]
# Target output:
# https://drive.google.com/file/d/1xM46aaDIeu4Z0FkikGOcmDoq7u2O47tY/view?usp=sharing
